# %%
import yfinance as yf
from datetime import  datetime
import pandas as pd

# %%
symbol = input("Symbol = ")
start_date = input(f"Start date = (YYYY-MM-DD)").strip()
end_date = input(f"End date = (YYYY-MM-DD)").strip()
interval = input("interval = (1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo)")  
mapping_symbol = {
    "0P0000HY8X.VN": "VNINDEX",
    "KO": "coca.cola",
    "BTC-USD": "btc"
}
stock = yf.Ticker(symbol)

# %%
stock.info
# Out:
# {'name': 'Bitcoin',
#  'startDate': 1278979200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,786,643. The last known price of Bitcoin is 98,053.41706869 USD and is down -0.48 over the last 24 hours. It is currently trading on 11806 active market(s) with $42,469,886,327.41 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 97939.48,
#  'open': 97939.48,
#  'dayLow': 97028.695,
#  'dayHigh': 98456.38,
#  'regularMarketPreviousClose': 97939.48,
#  'regularMarketOpen': 97939.48,
#  'regularMarketDayLow': 97028.695,
#  'regularMarketDayHigh': 98456.38,
#  'volume': 54762254336,
#  'regularMarketVolume': 54762254336,
#  'averageVolume': 40870905993,
#  'averageVolume10days': 70724367750,
#  'averageDailyVolume10Day': 70724367750,
#  'marketCap': 1948161671168,
#  'fiftyTwoWeekLow': 36750.13,
#  'fiftyTwoWeekHigh': 99655.5,
#  'fiftyDayAverage': 74341.85,
#  'twoHundredDayAverage': 65715.98,
#  'currency': 'USD',
#  'fromCurrency': 'BTC',
#  'toCurrency': 'USD=X',
#  'lastMarket': 'CoinMarketCap',
#  'coinMarketCapLink': 'https://coinmarketcap.com/currencies/bitcoin',
#  'volume24Hr': 54762254336,
#  'volumeAllCurrencies': 54762254336,
#  'circulatingSupply': 19787052,
#  'exchange': 'CCC',
#  'quoteType': 'CRYPTOCURRENCY',
#  'symbol': 'BTC-USD',
#  'underlyingSymbol': 'BTC-USD',
#  'shortName': 'Bitcoin USD',
#  'longName': 'Bitcoin USD',
#  'firstTradeDateEpochUtc': 1410912000,
#  'timeZoneFullName': 'UTC',
#  'timeZoneShortName': 'UTC',
#  'uuid': '74397779-1589-3270-8c45-b7f1a7345b3a',
#  'messageBoardId': 'finmb_BTC_CCC',
#  'trailingPegRatio': None}

# %%
hist = stock.history()

# %%
hist
# Out:
#                                    Open          High           Low  \
# Date
# 2024-10-25 00:00:00+00:00  68165.296875  68722.156250  65521.792969
# 2024-10-26 00:00:00+00:00  66628.734375  67317.921875  66360.593750
# 2024-10-27 00:00:00+00:00  67023.476562  68221.312500  66847.226562
# 2024-10-28 00:00:00+00:00  67922.671875  70212.265625  67535.132812
# 2024-10-29 00:00:00+00:00  69910.046875  73577.210938  69729.914062
# 2024-10-30 00:00:00+00:00  72715.367188  72905.296875  71411.734375
# 2024-10-31 00:00:00+00:00  72335.046875  72662.312500  69590.500000
# 2024-11-01 00:00:00+00:00  70216.898438  71559.015625  68779.703125
# 2024-11-02 00:00:00+00:00  69486.023438  69867.351562  69033.718750
# 2024-11-10 00:00:00+00:00  80474.187500   82570594495        0.0           0.0
# 2024-11-11 00:00:00+00:00  88701.484375  117966845037        0.0           0.0
# 2024-11-12 00:00:00+00:00  87955.812500  133673285375        0.0           0.0
# 2024-11-13 00:00:00+00:00  90584.164062  123559027869        0.0           0.0
# 2024-11-14 00:00:00+00:00  87250.429688   87616705248        0.0           0.0
# 2024-11-15 00:00:00+00:00  91066.007812   78243109518        0.0           0.0
# 2024-11-16 00:00:00+00:00  90558.476562   44333192814        0.0           0.0
# 2024-11-17 00:00:00+00:00  89845.851562   46350159305        0.0           0.0
# 2024-11-18 00:00:00+00:00  90542.640625   75535775084        0.0           0.0
# 2024-11-19 00:00:00+00:00  92343.789062   74521048295        0.0           0.0
# 2024-11-20 00:00:00+00:00  94339.492188   71730956426        0.0           0.0
# 2024-11-21 00:00:00+00:00  98504.726562  106024505582        0.0           0.0
# 2024-11-22 00:00:00+00:00  98997.664062   78473580551        0.0           0.0
# 2024-11-23 00:00:00+00:00  97777.281250   44414644677        0.0           0.0
# 2024-11-24 00:00:00+00:00  98013.820312   51712020623        0.0           0.0
# 2024-11-25 00:00:00+00:00  98456.382812   54762254336        0.0           0.0

# %%
hist = stock.history(
    start=start_date,
    interval=interval,
    end=end_date
)

# %%
str(hist.index.min().date())
# Out:
# '2014-09-17'

# %%
str(hist.index.max().date())
# Out:
# '2024-11-25'

# %%
hist.index = hist.index.strftime('%Y-%m-%d %H:%M:%S')
hist.index = pd.to_datetime(hist.index).tz_localize('UTC')

# %%
hist
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-11-21 00:00:00+00:00  94334.640625  99014.218750  94132.601562
# 2024-11-22 00:00:00+00:00  98496.429688  99655.500000  97222.664062
# 2024-11-23 00:00:00+00:00  99006.742188  99014.679688  97232.890625
# 2024-11-24 00:00:00+00:00  97778.093750  98647.179688  95788.078125
# 2024-11-25 00:00:00+00:00  97939.476562  98456.382812  97028.695312
#
#                                   Close        Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00    457.334015      21056800        0.0           0.0
# 2014-09-18 00:00:00+00:00    424.440002      34483200        0.0           0.0
# 2014-09-19 00:00:00+00:00    394.795990      37919700        0.0           0.0
# 2014-09-20 00:00:00+00:00    408.903992      36863600        0.0           0.0
# 2014-09-21 00:00:00+00:00    398.821014      26580100        0.0           0.0
# ...                                 ...           ...        ...           ...
# 2024-11-21 00:00:00+00:00  98504.726562  106024505582        0.0           0.0
# 2024-11-22 00:00:00+00:00  98997.664062   78473580551        0.0           0.0
# 2024-11-23 00:00:00+00:00  97777.281250   44414644677        0.0           0.0
# 2024-11-24 00:00:00+00:00  98013.820312   51712020623        0.0           0.0
# 2024-11-25 00:00:00+00:00  98456.382812   54762254336        0.0           0.0
#
# [3723 rows x 7 columns]

# %%
symbol =  mapping_symbol.get(symbol, symbol)

# %%
symbol = symbol.replace(".", "_").lower()

# %%
file_name = f"../../data/{symbol}/{symbol}-{str(hist.index.min().date())}-to-{str(hist.index.max().date())}_{interval}.csv"

# %%
file_name = file_name.replace("-", "_")

# %%
file_name
# Out:
# '../../data/btc/btc_2014_09_17_to_2024_11_25_1d.csv'

# %%
hist.to_csv(file_name)
