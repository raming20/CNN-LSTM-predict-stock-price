# %%
import yfinance as yf
from datetime import  datetime

# %%
symbol = "0P0000HY8X.VN"
stock = yf.Ticker(symbol)

# %%
stock.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 1264.48,
#  'regularMarketPreviousClose': 1264.48,
#  'fiftyTwoWeekLow': 1088.06,
#  'fiftyTwoWeekHigh': 1301.51,
#  'fiftyDayAverage': 1270.1718,
#  'twoHundredDayAverage': 1246.4135,
#  'currency': 'VND',
#  'exchange': 'VSE',
#  'quoteType': 'INDEX',
#  'symbol': '0P0000HY8X.VN',
#  'underlyingSymbol': '0P0000HY8X.VN',
#  'shortName': 'Vietnam VN Index",',
#  'longName': 'Vietnam VN Index',
#  'firstTradeDateEpochUtc': 1581472800,
#  'timeZoneFullName': 'Asia/Bangkok',
#  'timeZoneShortName': 'ICT',
#  'uuid': 'd7ccdc45-da20-3fb7-a255-ed9e89a9bacf',
#  'gmtOffSetMilliseconds': 25200000,
#  'trailingPegRatio': None}

# %%
datetime.fromtimestamp(1410912000)
# Out:
# datetime.datetime(2014, 9, 17, 7, 0)

# %%
hist = stock.history()

# %%
hist
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-10-14 00:00:00+07:00  1286.339966  1286.339966  1286.339966  1286.339966
# 2024-10-15 00:00:00+07:00  1281.079956  1281.079956  1281.079956  1281.079956
# 2024-10-16 00:00:00+07:00  1279.479980  1279.479980  1279.479980  1279.479980
# 2024-10-17 00:00:00+07:00  1286.520020  1286.520020  1286.520020  1286.520020
# 2024-10-18 00:00:00+07:00  1285.459961  1285.459961  1285.459961  1285.459961
# 2024-10-21 00:00:00+07:00  1279.770020  1279.770020  1279.770020  1279.770020
# 2024-10-22 00:00:00+07:00  1269.890015  1269.890015  1269.890015  1269.890015
# 2024-10-23 00:00:00+07:00  1270.900024  1270.900024  1270.900024  1270.900024
# 2024-10-24 00:00:00+07:00  1257.410034  1257.410034  1257.410034  1257.410034
# 2024-10-25 00:00:00+07:00  1252.719971  1252.719971  1252.719971  1252.719971
# 2024-10-28 00:00:00+07:00  1254.770020  1254.770020  1254.770020  1254.770020
# ...

# %%
hist = stock.history(
    start="2017-01-01"
)

# %%
str(hist.index.min().date())
# Out:
# '2020-02-12'

# %%
str(hist.index.max().date())
# Out:
# '2024-11-11'

# %%
hist
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-02-12 00:00:00+07:00   937.679993   937.679993   937.679993   937.679993
# 2020-02-13 00:00:00+07:00   938.239990   938.239990   938.239990   938.239990
# 2020-02-14 00:00:00+07:00   937.450012   937.450012   937.450012   937.450012
# 2020-02-18 00:00:00+07:00   927.929993   927.929993   927.929993   927.929993
# 2020-02-19 00:00:00+07:00   928.760010   928.760010   928.760010   928.760010
# ...                                ...          ...          ...          ...
# 2024-11-05 00:00:00+07:00  1245.760010  1245.760010  1245.760010  1245.760010
# 2024-11-06 00:00:00+07:00  1261.280029  1261.280029  1261.280029  1261.280029
# 2024-11-07 00:00:00+07:00  1259.750000  1259.750000  1259.750000  1259.750000
# 2024-11-08 00:00:00+07:00  1252.560059  1252.560059  1252.560059  1252.560059
# 2024-11-11 00:00:00+07:00  1250.319946  1250.319946  1250.319946  1250.319946
#
# ...

# %%
if symbol == "0P0000HY8X.VN":
    symbol = "VNINDEX"

# %%
symbol = symbol.replace(".", "_").lower()

# %%
file_name = f"./data/{symbol}-{str(hist.index.min().date())}-to-{str(hist.index.max().date())}.csv"

# %%
file_name = file_name.replace("-", "_")

# %%
file_name
# Out:
# './data/vnindex_2020_02_12_to_2024_11_11.csv'

# %%
hist.to_csv(file_name)
