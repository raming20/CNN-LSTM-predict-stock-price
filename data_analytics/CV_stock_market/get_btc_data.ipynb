# %%
import yfinance as yf
from datetime import  datetime

# %%
btc = yf.Ticker('BTC-USD')

# %%
btc.info
# Out:
# {'name': 'Bitcoin',
#  'startDate': 1278979200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,776,646. The last known price of Bitcoin is 69,579.71706891 USD and is up 0.13 over the last 24 hours. It is currently trading on 11793 active market(s) with $41,625,641,410.52 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 69346.72,
#  'open': 69346.72,
#  'dayLow': 68151.54,
#  'dayHigh': 69346.72,
#  'regularMarketPreviousClose': 69346.72,
#  'regularMarketOpen': 69346.72,
#  'regularMarketDayLow': 68151.54,
#  'regularMarketDayHigh': 69346.72,
#  'volume': 19885869056,
#  'regularMarketVolume': 19885869056,
#  'averageVolume': 31668401695,
#  'averageVolume10days': 37006387567,
#  'averageDailyVolume10Day': 37006387567,
#  'marketCap': 1347828842496,
# ...

# %%
datetime.fromtimestamp(1410912000)
# Out:
# datetime.datetime(2014, 9, 17, 7, 0)

# %%
hist = btc.history()

# %%
hist.index.min()
# Out:
# Timestamp('2024-10-03 00:00:00+0000', tz='UTC')

# %%
hist
# Out:
#                                    Open          High           Low  \
# Date
# 2024-10-03 00:00:00+00:00  60632.484375  61469.039062  59878.804688
# 2024-10-04 00:00:00+00:00  60754.625000  62465.992188  60459.941406
# 2024-10-05 00:00:00+00:00  62067.609375  62371.023438  61689.582031
# 2024-10-06 00:00:00+00:00  62084.988281  62959.570312  61833.148438
# 2024-10-07 00:00:00+00:00  62819.109375  64443.707031  62152.550781
# 2024-10-08 00:00:00+00:00  62221.644531  63174.304688  61843.562500
# 2024-10-09 00:00:00+00:00  62131.726562  62508.835938  60314.613281
# 2024-10-10 00:00:00+00:00  60581.929688  61236.722656  58895.207031
# 2024-10-11 00:00:00+00:00  60275.460938  63400.871094  60046.125000
# 2024-10-12 00:00:00+00:00  62444.617188  63448.785156  62443.269531
# 2024-10-13 00:00:00+00:00  63192.945312  63272.652344  62035.636719
# 2024-10-14 00:00:00+00:00  62848.398438  66482.492188  62442.152344
# 2024-10-15 00:00:00+00:00  66050.367188  67881.679688  64809.195312
# ...

# %%
hist = btc.history(
    start="2014-09-17"
)

# %%
hist.index.max()
# Out:
# Timestamp('2024-11-03 00:00:00+0000', tz='UTC')

# %%
hist
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-10-29 00:00:00+00:00  69910.046875  73577.210938  69729.914062
# 2024-10-30 00:00:00+00:00  72715.367188  72905.296875  71411.734375
# 2024-10-31 00:00:00+00:00  72335.046875  72662.312500  69590.500000
# 2024-11-01 00:00:00+00:00  70216.898438  71559.015625  68779.703125
# 2024-11-03 00:00:00+00:00  69346.718750  69346.718750  68123.492188
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# ...

# %%
hist.to_csv('btc-2024-09-17-to-2024-11-03')
