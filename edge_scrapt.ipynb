# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Edge()

driver.get('https://bing.com')

element = driver.find_element(By.ID, 'sb_form_q')
element.send_keys('WebDriver')
element.submit()

# %%
driver.get_log('browser')
# Out:
# [{'level': 'SEVERE',
#   'message': 'https://www.bing.com/?toWww=1&redig=6A24DF7F46A244038494496A67208FF1 0 [Report Only] Refused to load the script \'https://r.bing.com/rp/lmu8EBCaPRMKtay8LSArGyY3mv4.br.js\' because it violates the following Content Security Policy directive: "script-src https: \'strict-dynamic\' \'report-sample\' \'nonce-xETIG6qd9bRPTC7QGAEwSr0sH7r/fgVpkCCRLVqQjgg=\'". Note that \'strict-dynamic\' is present, so host-based allowlisting is disabled. Note that \'script-src-elem\' was not explicitly set, so \'script-src\' is used as a fallback.\n',
#   'source': 'security',
#   'timestamp': 1715665051299},
#  {'level': 'WARNING',
#   'message': "https://r.bing.com/rp/eKvcHdnNwo1WcxoSioV4ztnfZk8.br.js 0 Listener added for a 'DOMNodeInserted' mutation event. This event type is deprecated, and will be removed from this browser very soon. Usage of this event listener will cause performance issues today, and represents a large risk of future site breakage. Consider using MutationObserver instead. See https://chromestatus.com/feature/5083947249172480 for more information.",
#   'source': 'deprecation',
#   'timestamp': 1715665055814},
#  {'level': 'WARNING',
#   'message': "https://r.bing.com/rp/eKvcHdnNwo1WcxoSioV4ztnfZk8.br.js 0 Listener added for a 'DOMNodeRemoved' mutation event. This event type is deprecated, and will be removed from this browser very soon. Usage of this event listener will cause performance issues today, and represents a large risk of future site breakage. Consider using MutationObserver instead. See https://chromestatus.com/feature/5083947249172480 for more information.",
#   'source': 'deprecation',
#   'timestamp': 1715665055815},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665057758},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665058406},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665058406},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665058406},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665058406},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665058406},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/orgid/idtoken/conditional - An iframe which has both allow-scripts and allow-same-origin for its sandbox attribute can escape its sandboxing.',
#   'source': 'security',
#   'timestamp': 1715665059162},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665059309},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665059310},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665059310},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665059310},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665059310},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665059310},
#  {'level': 'WARNING',
#   'message': 'https://www.bing.com/search?q=WebDriver&form=QBLH - Third-party cookie will be blocked. Learn more in the Issues tab.',
#   'source': 'other',
#   'timestamp': 1715665059310}]

# %%
time.sleep(5)
driver.quit()
